# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudh9784/House-Price-prediction/blob/master/Pred_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.api as sm
from sklearn.metrics import r2_score

# %% [markdown]
# **Importing House data Set**

# %%
files.upload()
# Out:
#      <input type="file" id="files-722f0e6c-625c-43eb-9437-138235090539" name="files[]" multiple disabled />
#      <output id="result-722f0e6c-625c-43eb-9437-138235090539">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kc_house_data.csv to kc_house_data (2).csv
# ...

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  ...  yr_built  yr_renovated  zipcode
# 0  7129300520  20141013T000000  221900.0  ...      1955             0    98178
# 1  6414100192  20141209T000000  538000.0  ...      1951          1991    98125
# 2  5631500400  20150225T000000  180000.0  ...      1933             0    98028
# 3  2487200875  20141209T000000  604000.0  ...      1965             0    98136
# 4  1954400510  20150218T000000  510000.0  ...      1987             0    98074
#
# [5 rows x 17 columns]

# %%
df.describe()
# Out:
#                  id         price  ...  yr_renovated       zipcode
# count  2.161300e+04  2.161300e+04  ...  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05  ...     84.402258  98077.939805
# std    2.876566e+09  3.673622e+05  ...    401.679240     53.505026
# min    1.000102e+06  7.500000e+04  ...      0.000000  98001.000000
# 25%    2.123049e+09  3.219500e+05  ...      0.000000  98033.000000
# 50%    3.904930e+09  4.500000e+05  ...      0.000000  98065.000000
# 75%    7.308900e+09  6.450000e+05  ...      0.000000  98118.000000
# max    9.900000e+09  7.700000e+06  ...   2015.000000  98199.000000
#
# [8 rows x 16 columns]

# %%
X=df['price']

# %%
df.hist(bins=20,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f47d356d3c8>,
# ...
#       dtype=object)

# %%
df=df.drop('id',axis=1)
a=plt.subplots(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,cmap=sns.color_palette("Blues"))

# %%
X=df['grade'].values.reshape(-1,1)
Y=df['price'].values.reshape(-1,1)
lr=LinearRegression()

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred=lr.predict(X)

# %%
r2_score(Y,Y_pred)
# Out:
# 0.44550650957913185

# %%
plt.scatter(X,Y)
plt.plot(X,Y_pred,color='Black')

# %%
x2 = sm.add_constant(X)
ols = sm.OLS(Y, x2)
est = ols.fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                 1.736e+04
# Date:                Sun, 09 Jun 2019   Prob (F-statistic):               0.00
# Time:                        06:17:27   Log-Likelihood:            -3.0125e+05
# No. Observations:               21613   AIC:                         6.025e+05
# Df Residuals:                   21611   BIC:                         6.025e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.057e+06   1.23e+04    -86.195      0.000   -1.08e+06   -1.03e+06
# ...

# %%
X=df['sqft_living'].values.reshape(-1,1)
lr1=LinearRegression()
lr1.fit(X,Y)
Y2_pred=lr1.predict(X)

# %%
r2_score(Y,Y2_pred)
# Out:
# 0.49286538652201417

# %%
plt.scatter(X,Y,alpha=0.3,color='red')
plt.plot(X,Y2_pred,color='Black')

# %%
x2 = sm.add_constant(X)
ols = sm.OLS(Y, x2)
est = ols.fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.100e+04
# Date:                Sun, 09 Jun 2019   Prob (F-statistic):               0.00
# Time:                        06:17:27   Log-Likelihood:            -3.0028e+05
# No. Observations:               21613   AIC:                         6.006e+05
# Df Residuals:                   21611   BIC:                         6.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.387e+04   4405.455     -9.958      0.000   -5.25e+04   -3.52e+04
# ...
